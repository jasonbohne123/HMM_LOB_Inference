# %%
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from datetime import date,timedelta


import os
os.add_dll_directory('C:\Aorda\PSG\lib')
import psgpython as psg 
from psg_loader import load_psg

# %% [markdown]
# ### Script to iteratively Fit HMM model
# - Flexibility to fit via PSG constrained optimization or Hmmlearn Viterbi algorithm
# - Fits and returns model params across dataset

# %%
def remove_duplicates(series):
    """ Remove identical consecutive observations
    """
    cleaned_series=series[np.insert(np.diff(series).astype(bool), 0, True)]
    dropped_els=len(series)-len(cleaned_series)
    
    return cleaned_series


def prep_features(dt):
    """ Prep features by accessing grouped feature csv 
    """
    grouped_features=pd.read_csv(f'data/agg_features/grouped_features_{dt}.csv')
    bidsize=remove_duplicates(grouped_features['Bid_Size'].values)
    offersize=remove_duplicates(grouped_features['Offer_Size'].values)
    bookimbalance=remove_duplicates(grouped_features['OB_IB'].values)
    spread=remove_duplicates(grouped_features['spread'].values)

    feature_dict=dict(zip(['Bid_Size','Offer_Size','OB_IB','spread'],[bidsize,offersize,bookimbalance,spread]))

    return feature_dict

def extract_params(param_dict,method):
    """ Extract Params from optimized model 
    """
    if method==1:
        param_df=pd.DataFrame.from_dict(param_dict,orient='index',columns=['p1','p2','a11','a12', 'a21', 'a22','mu1','si1','mu2','si2'])

        # standardizing mu1 < mu2 as arbitrarily labeled, swapping mus and sigmas if needed 
        for x,row in param_df.iterrows():
            if row.loc['mu1']<row.loc['mu2']:
                continue
            mu1,mu2,sigma1,sigma2=row.loc['mu1'],row.loc['mu2'],row.loc['si1'],row.loc['si2']
            
            row.loc['mu1'],row.loc['mu2'],row.loc['si1'],row.loc['si2']=mu2,mu1,sigma2,sigma1

        param_df=param_df.drop(columns=['p1','p2'])
        return param_df

    elif method==2:
        param_df=pd.DataFrame.from_dict(param_dict,orient='index')
        means= pd.DataFrame(param_df['Mean'].to_list(),columns=['mu1','mu2'])
        covar=pd.DataFrame(param_df['Sigma'].to_list(), columns = ['sigma1', 'sigma2'])
        transit=pd.DataFrame(param_df['Transition'].to_list(), columns = ['a11', 'a12','a21','a22'])
        dates=pd.DataFrame(param_df.index,columns=['date'])
        
        new_param_df=pd.DataFrame(pd.concat([means,covar,transit,dates],axis=1))
        new_param_df.index=new_param_df['date'].values
        new_param_df=new_param_df.drop(columns=['date'])

       # standardizing mu1 < mu2 as arbitrarily labeled, swapping mus and sigmas if needed 
        for x,row in new_param_df.iterrows():
            if row.loc['mu1']<row.loc['mu2']:
                continue
            mu1,mu2,sigma1,sigma2=row.loc['mu1'],row.loc['mu2'],row.loc['sigma1'],row.loc['sigma2']
            
            row.loc['mu1'],row.loc['mu2'],row.loc['sigma1'],row.loc['sigma2']=mu2,mu1,sigma2,sigma1

        new_param_df=new_param_df[['a11','a12','a21','a22','mu1','sigma1','mu2','sigma2']]
        return new_param_df


def fit_hmm(method):
    """ Fit HMM model with PSG and HMMLearn 
    """
    start=date(2020,1,1)
    days=[start+timedelta(days=i) for i in range(0,30)]

    spread_params={}
    bidsize_params={}
    offersize_params={}
    bookimbalance_params={}
    
    # psg training
    if method==1:
        for dt in days:
            try:
                dt_features=prep_features(dt)
            except:
                continue
            
            # formatted as numpy float 
            np.savetxt(r'psg_text_hmm/vector_bidsize.txt', dt_features['Bid_Size'])
            np.savetxt(r'psg_text_hmm/vector_offersize.txt', dt_features['Offer_Size'])
            np.savetxt(r'psg_text_hmm/vector_bookimbalance.txt', dt_features['OB_IB'])
            np.savetxt(r'psg_text_hmm/vector_spread.txt', dt_features['spread'])


            psg_spread_prob = psg.psg_importfromtext('./psg_text_hmm/problem_hmm_normal_spread.txt')
            psg_spread_prob['problem_statement'] = '\n'.join(psg_spread_prob['problem_statement'])
            spread_solution=psg.psg_solver(psg_spread_prob)
            params=list(spread_solution.values())[4][1]
            spread_params[dt]=params

            psg_bidsize_prob = psg.psg_importfromtext('./psg_text_hmm/problem_hmm_normal_bidsize.txt')
            psg_bidsize_prob['problem_statement'] = '\n'.join(psg_bidsize_prob['problem_statement'])
            bidsize_solution=psg.psg_solver(psg_bidsize_prob)
            params=list(bidsize_solution.values())[4][1]
            bidsize_params[dt]=params

            psg_offersize_prob = psg.psg_importfromtext('./psg_text_hmm/problem_hmm_normal_offersize.txt')
            psg_offersize_prob['problem_statement'] = '\n'.join(psg_offersize_prob['problem_statement'])
            offersize_solution=psg.psg_solver(psg_offersize_prob)
            params=list(offersize_solution.values())[4][1]
            offersize_params[dt]=params

            psg_bookimbalance_prob = psg.psg_importfromtext('./psg_text_hmm/problem_hmm_normal_bookimbalance.txt')
            psg_bookimbalance_prob['problem_statement'] = '\n'.join(psg_bookimbalance_prob['problem_statement'])
            bookimbalance_solution=psg.psg_solver(psg_bookimbalance_prob)
            params=list(bookimbalance_solution.values())[4][1]
            bookimbalance_params[dt]=params
            
    elif method==2:
        for dt in days:
            
            try:
                dt_features=prep_features(dt)
            except:
                continue
            print(f"Fitting HMM usign HMM-Learn for {dt}")
            
            
            spread=dt_features['spread'].reshape(-1, 1)
            spread_model=GaussianHMM(n_components=2,algorithm='viterbi',covariance_type="spherical",min_covar=1e-4, n_iter=1000,tol=1e-8)
            fitted_spread_model=spread_model.fit(spread)
            spread_mu=fitted_spread_model.means_.flatten()
            spread_covar=fitted_spread_model.covars_.flatten()
            spread_transit=fitted_spread_model.transmat_.flatten()
            spread_params[dt]={"Mean":spread_mu, "Sigma":spread_covar,"Transition":spread_transit}

            bidsize=dt_features['Bid_Size'].reshape(-1, 1)
            bidsize_model=GaussianHMM(n_components=2,algorithm='viterbi',covariance_type="spherical",min_covar=1e-4, n_iter=1000,tol=1e-8)
            fitted_bidsize_model=bidsize_model.fit(bidsize)
            bidsize_mu=fitted_bidsize_model.means_.flatten()
            bidsize_covar=fitted_bidsize_model.covars_.flatten()
            bidsize_transit=fitted_bidsize_model.transmat_.flatten()
            bidsize_params[dt]={"Mean":bidsize_mu, "Sigma":bidsize_covar,"Transition":bidsize_transit}

            offersize=dt_features['Offer_Size'].reshape(-1, 1)
            offersize_model=GaussianHMM(n_components=2,algorithm='viterbi',covariance_type="spherical",min_covar=1e-4, n_iter=1000,tol=1e-8)
            fitted_offersize_model=offersize_model.fit(offersize)
            offersize_mu=fitted_offersize_model.means_.flatten()
            offersize_covar=fitted_offersize_model.covars_.flatten()
            offersize_transit=fitted_offersize_model.transmat_.flatten()
            offersize_params[dt]={"Mean":offersize_mu, "Sigma":offersize_covar,"Transition":offersize_transit}

            bookimbalance=dt_features['OB_IB'].reshape(-1, 1)
            bookimbalance_model=GaussianHMM(n_components=2,algorithm='viterbi',covariance_type="spherical",min_covar=1e-4, n_iter=1000,tol=1e-8)
            fitted_bookimbalance_model=bookimbalance_model.fit(bookimbalance)
            bookimbalance_mu=fitted_bookimbalance_model.means_.flatten()
            bookimbalance_covar=fitted_bookimbalance_model.covars_.flatten()
            bookimbalance_transit=fitted_bookimbalance_model.transmat_.flatten()
            bookimbalance_params[dt]={"Mean":bookimbalance_mu, "Sigma":bookimbalance_covar,"Transition":bookimbalance_transit}


    else:
        print("Not a valid method")
        return

    features_labels=["spread","bidsize","offersize","bookimbalance"]
    spread_df=extract_params(spread_params,method)
    bidsize_df=extract_params(bidsize_params,method)
    offersize_df=extract_params(offersize_params,method)
    bookimbalance_df=extract_params(bookimbalance_params,method)

    dict_df=dict(zip(features_labels,[spread_df,bidsize_df,offersize_df,bookimbalance_df]))
    return dict_df

# %% [markdown]
# ### PSG

# %%
psg_df=fit_hmm(method=1)
# Out:
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
#     100.0% of scenarios is processed
# 100% of vector_spread was read
# Start optimization
# Ext.iteration=0  Objective=0.740725099987E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.740725099987E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 32086.1760096 [-4.512213776820E+16]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 18.47, solving_time = 1.44
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 32086.1760096 [-4.512213776820E+16]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_spread) =  3.208617600959E+04
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bidsize was read
# Start optimization
# Ext.iteration=0  Objective=0.562587472260E+00  Residual=0.000000000000E+00
# Ext.iteration=72  Objective=0.582621660320E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.688106822136E+00  Residual=0.000000000000E+00
# Ext.iteration=234  Objective=0.688221209447E+00  Residual=0.000000000000E+00
# Ext.iteration=292  Objective=0.688221209447E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -1388.74744763 [-1.77816983722]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.14, preprocessing_time = 8.79, solving_time = 7.69
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -1388.74744763 [-1.77816983722]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bidsize) = -1.388747447629E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_offersize was read
# Start optimization
# Ext.iteration=0  Objective=0.598659916621E+00  Residual=0.000000000000E+00
# Ext.iteration=66  Objective=0.598659916630E+00  Residual=0.000000000000E+00
# Ext.iteration=132  Objective=0.598659916631E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.598659916631E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -1992.61805852 [-7.65680376719]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.14, preprocessing_time = 11.35, solving_time = 4.44
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -1992.61805852 [-7.65680376719]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_offersize) = -1.992618058523E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bookimbalance was read
# Start optimization
# Ext.iteration=0  Objective=0.912566134485E+00  Residual=0.000000000000E+00
# Ext.iteration=28  Objective=0.912566134485E+00  Residual=0.000000000000E+00
# Ext.iteration=56  Objective=0.912566134548E+00  Residual=0.000000000000E+00
# Ext.iteration=82  Objective=0.912566134548E+00  Residual=0.000000000000E+00
# Ext.iteration=105  Objective=0.912566134549E+00  Residual=0.000000000000E+00
# Ext.iteration=130  Objective=0.912566134549E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.912566134549E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -2916.85483052 [-3.995401977018E-02]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.12, preprocessing_time = 13.25, solving_time = 11.52
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -2916.85483052 [-3.995401977018E-02]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bookimbalance) = -2.916854830516E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_spread was read
# Start optimization
# Ext.iteration=0  Objective=0.647971182148E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.647971182148E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 36359.2945944 [-5.845053953933E+16]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0
Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Ext.iteration=110  Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Ext.iteration=120  Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Ext.iteration=131  Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Ext.iteration=142  Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.974792989142E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -2471.78837603 [-3.169632429080E-02]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.16, preprocessing_time = 31.26, solving_time = 30.56
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -2471.78837603 [-3.169632429080E-02]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bookimbalance) = -2.471788376026E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
#     100.0% of scenarios is processed
# 100% of vector_spread was read
# Start optimization
# Ext.iteration=0  Objective=0.640500920059E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.640500920059E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 38618.2496602 [-6.280606652730E+16]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.17, preprocessing_time = 31.91, solving_time = 3.27
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 38618.2496602 [-6.280606652730E+16]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_spread) =  3.861824966018E+04
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bidsize was read
# Start optimization
# Ext.iteration=0  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=28  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=62  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=88  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=117  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=136  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.672019408600E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -1679.19993937 [-3.123421581803E-02]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.16, preprocessing_time = 19.67, solving_time = 11.34
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -1679.19993937 [-3.123421581803E-02]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bidsize) = -1.679199939373E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_offersize was read
# Start optimization
# Ext.iteration=0  Objective=0.533402111032E+00  Residual=0.000000000000E+00
# Ext.iteration=26  Objective=0.533402111032E+00  Residual=0.000000000000E+00
# Ext.iteration=51  Objective=0.533402111276E+00  Residual=0.000000000000E+00
# Ext.iteration=84  Objective=0.533402111281E+00  Residual=0.000000000000E+00
# Ext.iteration=110  Objective=0.533402111281E+00  Residual=0.000000000000E+00
# Ext.iteration=139  Objective=0.533402111291E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.533402111315E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -2064.12763624 [-17.3371439401]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.20, preprocessing_time = 21.66, solving_time = 10.95
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -2064.12763624 [-17.3371439401]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_offersize) = -2.064127636236E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bookimbalance was read
# Start optimization
# Ext.iteration=0  Objective=0.766803301296E+00  Residual=0.000000000000E+00
# Ext.iteration=11  Objective=0.766803301296E+00  Residual=0.000000000000E+00
# Ext.iteration=20  Objective=0.766803301296E+00  Residual=0.000000000000E+00
# Ext.iteration=31  Objective=0.766803301296E+00  Residual=0.000000000000E+00
# Ext.iteration=43  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=53  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=64  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=74  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=83  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=94  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=102  Objective=0.766803301319E+00  Residual=0.000000000000E+00
# Ext.iteration=112  Objective=0.766803301702E+00  Residual=0.000000000000E+00
# Ext.iteration=122  Objective=0.766803301702E+00  Residual=0.000000000000E+00
# Ext.iteration=134  Objective=0.766803301702E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.766803301702E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -2878.90576583 [-48.0734189748]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.12, preprocessing_time = 35.27, solving_time = 29.79
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -2878.90576583 [-48.0734189748]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bookimbalance) = -2.878905765827E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_spread was read
# Start optimization
# Ext.iteration=0  Objective=0.683003486310E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.683003486310E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 19569.9362406 [-2.984662693420E+16]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.14, preprocessing_time = 17.50, solving_time = 1.33
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 19569.9362406 [-2.984662693420E+16]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_spread) =  1.956993624061E+04
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bidsize was read
# Start optimization
# Ext.iteration=0  Objective=0.727556635037E+00  Residual=0.000000000000E+00
# Ext.iteration=79  Objective=0.727556635038E+00  Residual=0.000000000000E+00
# Ext.iteration=141  Objective=0.727556635038E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.727556635038E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = -1665.95073832 [-1787.43440097]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.14, preprocessing_time = 9.92, solving_time = 4.17
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -1665.95073832 [-1787.43440097]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bidsize) = -1.665950738320E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_offersize was read
# Start optimization
# Ext.iteration=0  Objective=0.582988740541E+00  Residual=0.000000000000E+00
# Ext.iteration=105  Objective=0.582988740541E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.582988740541E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -196.700239504 [-1.924167446519E-02]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.13, preprocessing_time = 8.73, solving_time = 3.18
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -196.700239504 [-1.924167446519E-02]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_offersize) = -1.967002395042E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bookimbalance was read
# Start optimization
# Ext.iteration=0  Objective=0.932601600722E+00  Residual=0.000000000000E+00
# Ext.iteration=33  Objective=0.932601600722E+00  Residual=0.000000000000E+00
# Ext.iteration=73  Objective=0.932601600723E+00  Residual=0.000000000000E+00
# Ext.iteration=104  Objective=0.932601600723E+00  Residual=0.000000000000E+00
# Ext.iteration=142  Objective=0.932601600723E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.932601600723E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -1498.65398155 [-2.008700687925E-02]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 211.058500969 [-3.124193786234E+14]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_spread) =  2.110585009686E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bidsize was read
# Start optimization
# Ext.iteration=0  Objective=0.872604490303E+00  Residual=0.000000000000E+00
# Ext.iteration=63  Objective=0.872604490303E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = -127.675354095 [-1.103659200946E-07]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 0.73, solving_time = 0.07
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -127.675354095 [-1.103659200946E-07]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bidsize) = -1.276753540954E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_offersize was read
# Start optimization
# Ext.iteration=0  Objective=0.523067927249E+00  Residual=0.000000000000E+00
# Ext.iteration=31  Objective=0.523067927249E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = -133.732302611 [-9.882667756148E-08]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.12, preprocessing_time = 0.45, solving_time = 0.02
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -133.732302611 [-9.882667756148E-08]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_offersize) = -1.337323026108E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bookimbalance was read
# Start optimization
# Ext.iteration=0  Objective=0.780856135120E+00  Residual=0.000000000000E+00
# Ext.iteration=144  Objective=0.780856135121E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is feasible
# Calculating resulting outputs. Writing solution.
# Objective: objective = -154.126038436 [-2.467260477057E-03]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = feasible
# Timing: data_loading_time = 0.15, preprocessing_time = 0.82, solving_time = 0.15
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = -154.126038436 [-2.467260477057E-03]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bookimbalance) = -1.541260384364E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_spread was read
# Start optimization
# Ext.iteration=0  Objective=0.577274130864E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.577274130864E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 23327.3189237 [-4.209315686667E+16]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.14, preprocessing_time = 20.32, solving_time = 1.77
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 23327.3189237 [-4.209315686667E+16]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_spread) =  2.332731892372E+04
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bidsize was read
# Start optimization
# Ext.iteration=0  Objective=0.663366852767E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.663366852767E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 344.776868799 [-5.413936047119E+14]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 8.52, solving_time = 0.25
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 344.776868799 [-5.413936047119E+14]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bidsize) =  3.447768687995E+02
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_offersize was read
# Start optimization
# Ext.iteration=0  Objective=0.578588633895E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.578588633895E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 1525.06978088 [-2.745671556649E+15]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.11, preprocessing_time = 9.06, solving_time = 0.36
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 1525.06978088 [-2.745671556649E+15]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_offersize) =  1.525069780882E+03
# OK. Solver Finished
#
# OK. Problem Imported
#
# Running solver
# Reading problem formulation
# Warning: 1 Object: Problem analizing	Message: Problem Statement: objective may be non-convex
# Asking for data information
# Getting data
# 100% of vector_bookimbalance was read
# Start optimization
# Ext.iteration=0  Objective=0.843839059312E+00  Residual=0.000000000000E+00
# Ext.iteration=10  Objective=0.843839059312E+00  Residual=0.000000000000E+00
# Optimization is stopped
# Solution is optimal
# Calculating resulting outputs. Writing solution.
# Objective: objective = 487.112674443 [-6.013102027915E+14]
# Solver has normally finished. Solution was saved.
# Problem: problem_hmm_normal, solution_status = optimal
# Timing: data_loading_time = 0.09, preprocessing_time = 12.45, solving_time = 0.67
# Variables: optimal_point = point_problem_hmm_normal
# Objective: objective = 487.112674443 [-6.013102027915E+14]
# Constraint: sum_of_probabilities_for_states = vector_sum_of_probabilities_for_states
# Function: hmm_normal(2,vector_bookimbalance) =  4.871126744431E+02
# OK. Solver Finished

# %%
for feature,df in psg_df.items():
    print(f"Feature {feature} df saved")
    df.to_csv(f'data/results/psg_{feature}.csv')
    psg_df[feature]=df.rename(columns={'si1':'sigma1','si2':'sigma2'})
# Out:
# Feature spread df saved
# Feature bidsize df saved
# Feature offersize df saved
# Feature bookimbalance df saved

# %% [markdown]
# ### HMM Model

# %%
hmm_df=fit_hmm(method=2)
# Out:
# Fitting HMM usign HMM-Learn for 2020-01-02
# Fitting HMM usign HMM-Learn for 2020-01-03
# Fitting HMM usign HMM-Learn for 2020-01-06
# Fitting HMM usign HMM-Learn for 2020-01-07
# Fitting HMM usign HMM-Learn for 2020-01-08
# Fitting HMM usign HMM-Learn for 2020-01-09
# Fitting HMM usign HMM-Learn for 2020-01-10
# Fitting HMM usign HMM-Learn for 2020-01-13
# Fitting HMM usign HMM-Learn for 2020-01-14
# Fitting HMM usign HMM-Learn for 2020-01-15
# Fitting HMM usign HMM-Learn for 2020-01-16
# Fitting HMM usign HMM-Learn for 2020-01-17
# Fitting HMM usign HMM-Learn for 2020-01-21
# Fitting HMM usign HMM-Learn for 2020-01-22
# Fitting HMM usign HMM-Learn for 2020-01-23
# Fitting HMM usign HMM-Learn for 2020-01-24
# Fitting HMM usign HMM-Learn for 2020-01-27
# Fitting HMM usign HMM-Learn for 2020-01-28
# Fitting HMM usign HMM-Learn for 2020-01-29
# Fitting HMM usign HMM-Learn for 2020-01-30

# %%
for feature,df in hmm_df.items():
    print(f"Feature {feature} df saved")
    df.to_csv(f'data/results/hmm_{feature}.csv')
# Out:
# Feature spread df saved
# Feature bidsize df saved
# Feature offersize df saved
# Feature bookimbalance df saved

# %% [markdown]
# ### Parameter Estimates for HMM on Spread

# %%
psg_df['spread'].describe()
# Out:
#              a11        a12        a21        a22        mu1     sigma1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.806272   0.193728   0.133529   0.866471   0.060623   0.020881
# std     0.105667   0.105667   0.098822   0.098822   0.067114   0.034069
# min     0.569270   0.046254   0.028994   0.660056   0.034876   0.009084
# 25%     0.729465   0.103503   0.068379   0.825096   0.038810   0.010491
# 50%     0.797302   0.202698   0.094486   0.905514   0.043875   0.011771
# 75%     0.896497   0.270535   0.174904   0.931621   0.050290   0.015209
# max     0.953746   0.430730   0.339944   0.971006   0.342463   0.164497
#
#              mu2     sigma2
# count  20.000000  20.000000
# mean    0.181856   0.122592
# std     0.133457   0.063987
# min     0.106166   0.076417
# 25%     0.120530   0.088471
# 50%     0.141912   0.100189
# 75%     0.175490   0.108457
# max     0.709377   0.286053

# %%
hmm_df['spread'].describe()
# Out:
#              a11        a12        a21        a22        mu1     sigma1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.885729   0.114271   0.212052   0.787948   0.060675   0.001542
# std     0.076464   0.076464   0.109721   0.109721   0.067108   0.006011
# min     0.722159   0.028971   0.054669   0.568398   0.034913   0.000085
# 25%     0.856195   0.067210   0.103314   0.713064   0.038854   0.000112
# 50%     0.906327   0.093673   0.232466   0.767534   0.043936   0.000141
# 75%     0.932790   0.143805   0.286936   0.896686   0.050359   0.000234
# max     0.971029   0.277841   0.431602   0.945331   0.342480   0.027074
#
#              mu2     sigma2
# count  20.000000  20.000000
# mean    0.182230   0.018964
# std     0.133380   0.022522
# min     0.106534   0.005854
# 25%     0.120932   0.007856
# 50%     0.142390   0.010063
# 75%     0.175794   0.011787
# max     0.709358   0.082092

# %%
spread_err=psg_df['spread'].describe()-hmm_df['spread'].describe()
spread_err
# Out:
#             a11       a12       a21       a22       mu1    sigma1       mu2  \
# count  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# mean  -0.079457  0.079457 -0.078524  0.078524 -0.000052  0.019339 -0.000374
# std    0.029202  0.029202 -0.010899 -0.010899  0.000005  0.028057  0.000077
# min   -0.152889  0.017283 -0.025674  0.091658 -0.000037  0.009000 -0.000368
# 25%   -0.126730  0.036293 -0.034935  0.112033 -0.000044  0.010379 -0.000402
# 50%   -0.109024  0.109024 -0.137980  0.137980 -0.000061  0.011629 -0.000478
# 75%   -0.036293  0.126730 -0.112033  0.034935 -0.000069  0.014974 -0.000303
# max   -0.017283  0.152889 -0.091658  0.025674 -0.000018  0.137423  0.000019
#
#          sigma2
# count  0.000000
# mean   0.103628
# std    0.041465
# min    0.070563
# 25%    0.080614
# 50%    0.090126
# 75%    0.096670
# max    0.203960

# %%
pd.DataFrame(100*spread_err.loc['mean']/psg_df['spread'].describe().loc['mean']).T
# Out:
#            a11        a12        a21       a22      mu1     sigma1       mu2  \
# mean -9.854877  41.014793 -58.806522  9.062456 -0.08515  92.613461 -0.205678
#
#          sigma2
# mean  84.530947

# %% [markdown]
# ### Parameter Estimates for HMM on Bidsize

# %%
psg_df['bidsize'].describe()
# Out:
#              a11        a12        a21        a22        mu1        si1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.775628   0.224372   0.057393   0.942607   1.070006   0.219555
# std     0.215686   0.215686   0.041205   0.041205   0.098283   0.023631
# min     0.143900   0.010338   0.001707   0.864498   0.930758   0.177427
# 25%     0.643866   0.037887   0.019853   0.910883   0.960312   0.200530
# 50%     0.839800   0.160200   0.062197   0.937803   1.072182   0.221013
# 75%     0.962113   0.356134   0.089117   0.980147   1.149388   0.235914
# max     0.989662   0.856100   0.135502   0.998293   1.206650   0.270283
#
#              mu2        si2
# count  20.000000  20.000000
# mean    1.466907   0.370816
# std     0.206305   0.169462
# min     1.213040   0.149726
# 25%     1.279580   0.258228
# 50%     1.424300   0.311933
# 75%     1.569670   0.441264
# max     1.964026   0.801932

# %%
hmm_df['bidsize'].describe()
# Out:
#              a11        a12        a21        a22        mu1     sigma1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.920191   0.079809   0.113107   0.886893   1.022551   0.047892
# std     0.089367   0.089367   0.130762   0.130762   0.091619   0.018063
# min     0.588843   0.002972   0.010337   0.489804   0.930780   0.031489
# 25%     0.903108   0.023483   0.026223   0.893503   0.946616   0.038510
# 50%     0.937814   0.062186   0.079808   0.920192   0.981811   0.041331
# 75%     0.976517   0.096892   0.106497   0.973777   1.069392   0.051964
# max     0.997028   0.411157   0.510196   0.989663   1.206646   0.113643
#
#              mu2     sigma2
# count  20.000000  20.000000
# mean    1.374949   0.119690
# std     0.208620   0.145450
# min     1.202485   0.029626
# 25%     1.242078   0.061052
# 50%     1.278980   0.073684
# 75%     1.408916   0.099618
# max     1.964034   0.643217

# %%
bidsize_err=psg_df['bidsize'].describe()-hmm_df['bidsize'].describe()
bidsize_err
# Out:
#             a11       a12       a21       a22       mu1    sigma1       mu2  \
# count  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# mean  -0.144563  0.144563 -0.055714  0.055714  0.047455  0.171663  0.091957
# std    0.126319  0.126319 -0.089557 -0.089557  0.006664  0.005568 -0.002316
# min   -0.444943  0.007366 -0.008630  0.374694 -0.000022  0.145938  0.010555
# 25%   -0.259242  0.014404 -0.006371  0.017380  0.013696  0.162021  0.037502
# 50%   -0.098014  0.098014 -0.017611  0.017611  0.090371  0.179682  0.145320
# 75%   -0.014404  0.259242 -0.017380  0.006371  0.079996  0.183950  0.160754
# max   -0.007366  0.444943 -0.374694  0.008630  0.000004  0.156640 -0.000008
#
#          sigma2
# count  0.000000
# mean   0.251126
# std    0.024012
# min    0.120100
# 25%    0.197176
# 50%    0.238249
# 75%    0.341646
# max    0.158716

# %%
pd.DataFrame(100*bidsize_err.loc['mean']/psg_df['bidsize'].describe().loc['mean']).T
# Out:
#             a11        a12        a21       a22       mu1   sigma1       mu2  \
# mean -18.638133  64.430033 -97.075327  5.910633  4.435003  78.1867  6.268789
#
#          sigma2
# mean  67.722447

# %% [markdown]
# ### Parameter Estimates for HMM on OfferSize

# %%
psg_df['offersize'].describe()
# Out:
#              a11        a12        a21        a22        mu1        si1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.799846   0.200154   0.104828   0.895172   1.101590   0.215371
# std     0.266062   0.266062   0.218270   0.218270   0.107237   0.060179
# min     0.000000   0.005760   0.000442   0.000000   0.862478   0.000001
# 25%     0.731759   0.043505   0.006716   0.874183   1.018361   0.202605
# 50%     0.939493   0.060507   0.028757   0.971243   1.089679   0.218045
# 75%     0.956495   0.268241   0.125817   0.993284   1.192509   0.241782
# max     0.994240   1.000000   1.000000   0.999558   1.243101   0.293308
#
#              mu2        si2
# count  20.000000  20.000000
# mean    1.435147   0.356690
# std     0.288689   0.195105
# min     1.183280   0.113905
# 25%     1.258970   0.269635
# 50%     1.299874   0.277071
# 75%     1.526534   0.351048
# max     2.141238   0.866924

# %%
hmm_df['offersize'].describe()
# Out:
#                 a11        a12        a21            a22        mu1  \
# count  2.000000e+01  20.000000  20.000000   2.000000e+01  20.000000
# mean   6.505255e-01   0.349475   0.365502   6.344976e-01   1.075612
# std    3.884013e-01   0.388401   0.393324   3.933239e-01   0.084543
# min    7.887506e-95   0.010218   0.009802  4.004058e-151   0.862487
# 25%    4.305699e-01   0.050448   0.047887   2.892175e-01   1.020520
# 50%    8.668956e-01   0.133104   0.122369   8.776311e-01   1.098612
# 75%    9.495518e-01   0.569430   0.710783   9.521134e-01   1.098612
# max    9.897821e-01   1.000000   1.000000   9.901982e-01   1.239977
#
#           sigma1        mu2     sigma2
# count  20.000000  20.000000  20.000000
# mean    0.033295   1.262011   0.099223
# std     0.027891   0.041947   0.110859
# min     0.000003   1.182793   0.027779
# 25%     0.000004   1.244576   0.072063
# 50%     0.039326   1.251964   0.075506
# 75%     0.051208   1.299280   0.085959
# max     0.075778   1.339824   0.563636

# %%
offersize_err=psg_df['offersize'].describe()-hmm_df['offersize'].describe()
offersize_err
# Out:
#                 a11           a12           a21            a22       mu1  \
# count  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00  0.000000
# mean   1.493208e-01 -1.493208e-01 -2.606748e-01   2.606748e-01  0.025979
# std   -1.223393e-01 -1.223393e-01 -1.750540e-01  -1.750540e-01  0.022694
# min   -7.887506e-95 -4.458136e-03 -9.359762e-03 -4.004058e-151 -0.000009
# 25%    3.011891e-01 -6.943297e-03 -4.117016e-02   5.849653e-01 -0.002159
# 50%    7.259756e-02 -7.259756e-02 -9.361216e-02   9.361216e-02 -0.008933
# 75%    6.943297e-03 -3.011891e-01 -5.849653e-01   4.117016e-02  0.093896
# max    4.458136e-03 -8.104628e-15 -1.053602e-13   9.359762e-03  0.003123
#
#          sigma1       mu2    sigma2
# count  0.000000  0.000000  0.000000
# mean   0.182076  0.173136  0.257467
# std    0.032288  0.246743  0.084246
# min   -0.000002  0.000487  0.086125
# 25%    0.202601  0.014394  0.197572
# 50%    0.178719  0.047911  0.201564
# 75%    0.190574  0.227254  0.265089
# max    0.217530  0.801414  0.303288

# %%
pd.DataFrame(100*offersize_err.loc['mean']/psg_df['offersize'].describe().loc['mean']).T
# Out:
#             a11        a12         a21        a22      mu1     sigma1  \
# mean  18.668686 -74.603058 -248.670116  29.120065  2.35828  84.540556
#
#             mu2     sigma2
# mean  12.063981  72.182228

# %% [markdown]
# ### Parameter Estimes for HMM on BookImbalance

# %%
psg_df['bookimbalance'].describe()
# Out:
#              a11        a12        a21        a22        mu1        si1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.859427   0.140573   0.104604   0.895396   0.656760   0.209200
# std     0.084247   0.084247   0.066329   0.066329   0.066811   0.021918
# min     0.639234   0.023580   0.030673   0.761885   0.503831   0.169518
# 25%     0.838370   0.097462   0.043665   0.849729   0.613157   0.195624
# 50%     0.881739   0.118261   0.087388   0.912612   0.666259   0.208292
# 75%     0.902538   0.161630   0.150271   0.956335   0.709919   0.221199
# max     0.976420   0.360766   0.238115   0.969327   0.757812   0.245684
#
#              mu2        si2
# count  20.000000  20.000000
# mean    1.031110   0.318886
# std     0.129750   0.110057
# min     0.893228   0.248889
# 25%     0.975975   0.284053
# 50%     1.008497   0.297682
# 75%     1.030171   0.308650
# max     1.522145   0.780560

# %%
hmm_df['bookimbalance'].describe()
# Out:
#              a11        a12        a21        a22        mu1     sigma1  \
# count  20.000000  20.000000  20.000000  20.000000  20.000000  20.000000
# mean    0.842937   0.157063   0.158365   0.841635   0.668789   0.047312
# std     0.170552   0.170552   0.181151   0.181151   0.073893   0.016688
# min     0.178968   0.031642   0.023576   0.165240   0.503867   0.028746
# 25%     0.828680   0.054544   0.074421   0.864808   0.627313   0.038272
# 50%     0.869033   0.130967   0.115979   0.884021   0.681110   0.043393
# 75%     0.945456   0.171320   0.135192   0.925579   0.713346   0.054976
# max     0.968358   0.821032   0.834760   0.976424   0.822439   0.106498
#
#              mu2     sigma2
# count  20.000000  20.000000
# mean    1.023137   0.114361
# std     0.137635   0.117042
# min     0.822539   0.061964
# 25%     0.966517   0.080691
# 50%     1.008515   0.089850
# 75%     1.030171   0.095753
# max     1.522328   0.609443

# %%
bookimbalance_err=psg_df['bookimbalance'].describe()-hmm_df['bookimbalance'].describe()
bookimbalance_err
# Out:
#             a11       a12       a21       a22       mu1    sigma1  \
# count  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# mean   0.016491 -0.016491 -0.053761  0.053761 -0.012028  0.161888
# std   -0.086305 -0.086305 -0.114823 -0.114823 -0.007082  0.005230
# min    0.460266 -0.008062  0.007097  0.596645 -0.000036  0.140772
# 25%    0.009690  0.042918 -0.030755 -0.015078 -0.014157  0.157352
# 50%    0.012706 -0.012706 -0.028590  0.028590 -0.014850  0.164899
# 75%   -0.042918 -0.009690  0.015078  0.030755 -0.003427  0.166223
# max    0.008062 -0.460266 -0.596645 -0.007097 -0.064627  0.139185
#
#                 mu2    sigma2
# count  0.000000e+00  0.000000
# mean   7.972553e-03  0.204524
# std   -7.884963e-03 -0.006985
# min    7.068898e-02  0.186925
# 25%    9.458404e-03  0.203362
# 50%   -1.807641e-05  0.207832
# 75%   -8.009914e-07  0.212896
# max   -1.829136e-04  0.171116

# %%
pd.DataFrame(100*bookimbalance_err.loc['mean']/psg_df['bookimbalance'].describe().loc['mean']).T
# Out:
#            a11        a12        a21       a22       mu1     sigma1       mu2  \
# mean  1.918781 -11.730973 -51.394934  6.004156 -1.831481  77.384149  0.773201
#
#          sigma2
# mean  64.137179
